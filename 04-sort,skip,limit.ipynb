# %%
from pymongo import MongoClient, DESCENDING
import pprint
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\TRETEC\Documents\Python\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\TRETEC\AppData\Local\Temp\ipykernel_8308\2234015493.py", line 1, in <cell line: 1>
#     from pymongo import MongoClient, DESCENDING
#   File "c:\Users\TRETEC\Documents\Python\lib\site-packages\pymongo\__init__.py", line 101, in <module>
#     from pymongo import _csot
#   File "c:\Users\TRETEC\Documents\Python\lib\site-packages\pymongo\_csot.py", line 22, in <module>
#     from pymongo.write_concern import WriteConcern
#   File "c:\Users\TRETEC\Documents\Python\lib\site-packages\pymongo\write_concern.py", line 19, in <module>
#     from pymongo.errors import ConfigurationError
#   File "c:\Users\TRETEC\Documents\Python\lib\site-packages\pymongo\errors.py", line 18, in <module>
# ...

# %%
# Replace XXXX with your connection URI from the Atlas UI
course_cluster_uri = XXX

# %%
from pymongo import MongoClient, DESCENDING
import pprint

client = MongoClient(course_cluster_uri)

db = client.sample_mflix

# %%
filters = {}
page = 0
movies_per_page = 20

# %%
# key to the value that we will be sorting depending on it
sort_key = "tomatoes.viewer.numReviews"

# we filter the movies' collection then we sort the result depending on number of reviews
# in order to get the most watched movies
# at first, filters will be blank, hence we will be taking the whole collection into consideration
movies_to_be_displayed = db.movies.find(filters).sort(sort_key, DESCENDING)

# %%
# in order to implement pagination we will need to 
# limit of on screen movies list to only 20 movies
# and at the same time skip the list of movies that the user had seen
movies_on_screen = movies_to_be_displayed.skip(page * movies_per_page).limit(movies_per_page)

# %%
list_of_movies_on_screen = list(movies_on_screen)

pprint.pprint(list_of_movies_on_screen)

print(len(list_of_movies_on_screen))

# on screen, the top 20 movie right then
# Out:
# [{'_id': ObjectId('573a139af29313caabcf0d74'),
#   'awards': {'nominations': 63,
#              'text': 'Won 11 Oscars. Another 116 wins & 63 nominations.',
#              'wins': 127},
#   'cast': ['Leonardo DiCaprio', 'Kate Winslet', 'Billy Zane', 'Kathy Bates'],
#   'countries': ['USA'],
#   'directors': ['James Cameron'],
#   'fullplot': '84 years later, a 101-year-old woman named Rose DeWitt Bukater '
#               'tells the story to her granddaughter Lizzy Calvert, Brock '
#               'Lovett, Lewis Bodine, Bobby Buell and Anatoly Mikailavich on '
#               'the Keldysh about her life set in April 10th 1912, on a ship '
#               'called Titanic when young Rose boards the departing ship with '
#               'the upper-class passengers and her mother, Ruth DeWitt Bukater, '
#               'and her fiancè, Caledon Hockley. Meanwhile, a drifter and '
#               'artist named Jack Dawson and his best friend Fabrizio De Rossi '
# ...

# %%
# we simulate the action of going to the second page
page = 1

# %%
movies_to_be_displayed = db.movies.find(filters).sort(sort_key, DESCENDING).skip(movies_per_page * page).limit(movies_per_page)

list_of_movies_on_screen = list(movies_to_be_displayed)

pprint.pprint(list_of_movies_on_screen)
# Out:
# [{'fullplot': 'As Paleoclimatologist named Jack Hall is in Antartica, he '
#               'discovers that a huge ice sheet has sheared off. But what he '
#               'does not know is that this event will trigger a massive climate '
#               'shift that will affect the world population. Meanwhile, his son '
#               'Sam is with friends in New York to attend an event. There they '
#               'discover that it has been raining non-stop for the past 3 '
#               'weeks, and after a series of weather-related disasters begin to '
#               'occur over the world, everybody realizes the world is entering '
#               'a new Ice Age and the world population begins trying to '
#               'evacuate to the warmer climates of the south. Jack makes a '
#               'daring attempt to rescue his son and his friends who are stuck '
#               'in New York and who have managed to survive not only a massive '
# ...
